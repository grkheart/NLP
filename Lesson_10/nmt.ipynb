# %% [markdown]
# # Neural machine translation

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# Out:
# --2021-04-30 13:24:46--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 104.21.55.222, 172.67.173.198, 2606:4700:3031::6815:37de, ...
# Connecting to www.manythings.org (www.manythings.org)|104.21.55.222|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14042100 (13M) [application/zip]
# Saving to: ‘rus-eng.zip’
#
# rus-eng.zip         100%[===================>]  13.39M  5.93MB/s    in 2.3s
#
# 2021-04-30 13:24:48 (5.93 MB/s) - ‘rus-eng.zip’ saved [14042100/14042100]

# %%
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# Archive:  rus-eng.zip
#   inflating: rus-eng/rus.txt
#   inflating: rus-eng/_about.txt

# %%
# !ls /content/rus-eng/ -lah
# Out:
# total 67M
# drwxr-xr-x 2 root root 4.0K Apr 30 13:24 .
# drwxr-xr-x 1 root root 4.0K Apr 30 13:24 ..
# -rw-r--r-- 1 root root 1.5K Jan 24 02:56 _about.txt
# -rw-r--r-- 1 root root  67M Jan 24 02:56 rus.txt

# %%
# Download the file
path_to_file = "/content/rus-eng/rus.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[0])
print(ru[0])
# Out:
# <start> go . <end>
# <start> марш ! <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (421765, 421765)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 19 ----> он
# 11074 ----> помешан
# 20 ----> на
# 11075 ----> всяких
# 16889 ----> девайсах
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 118 ----> he's
# 9 ----> a
# 4845 ----> gadget
# 3230 ----> freak
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
# print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

  def call(self, x, hidden):
    # enc_output shape == (batch_size, max_length, hidden_size)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x, initial_state=hidden)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %%
decoder_sample_x.shape
# Out:
# TensorShape([64, 7148])

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 1024])

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.7902
# Epoch 1 Batch 100 Loss 1.9833
# Epoch 1 Batch 200 Loss 1.7791
# Epoch 1 Batch 300 Loss 1.6809
# Epoch 1 Batch 400 Loss 1.4369
# Epoch 1 Batch 500 Loss 1.4370
# Epoch 1 Batch 600 Loss 1.3572
# Epoch 1 Batch 700 Loss 1.2917
# Epoch 1 Batch 800 Loss 1.1861
# Epoch 1 Batch 900 Loss 1.1023
# Epoch 1 Batch 1000 Loss 1.1265
# Epoch 1 Batch 1100 Loss 0.9643
# Epoch 1 Batch 1200 Loss 0.9193
# Epoch 1 Loss 1.4308
# Time taken for 1 epoch 226.83557391166687 sec
#
# Epoch 2 Batch 0 Loss 0.8729
# Epoch 2 Batch 100 Loss 0.9116
# Epoch 2 Batch 200 Loss 0.8501
# Epoch 2 Batch 300 Loss 0.7734
# Epoch 2 Batch 400 Loss 0.6958
# Epoch 2 Batch 500 Loss 0.7630
# Epoch 2 Batch 600 Loss 0.6321
# Epoch 2 Batch 700 Loss 0.6941
# Epoch 2 Batch 800 Loss 0.6622
# Epoch 2 Batch 900 Loss 0.6241
# Epoch 2 Batch 1000 Loss 0.5796
# Epoch 2 Batch 1100 Loss 0.5707
# Epoch 2 Batch 1200 Loss 0.6748
# Epoch 2 Loss 0.7017
# Time taken for 1 epoch 213.73066639900208 sec
#
# Epoch 3 Batch 0 Loss 0.3733
# Epoch 3 Batch 100 Loss 0.3921
# Epoch 3 Batch 200 Loss 0.3475
# Epoch 3 Batch 300 Loss 0.3728
# Epoch 3 Batch 400 Loss 0.3189
# Epoch 3 Batch 500 Loss 0.3719
# Epoch 3 Batch 600 Loss 0.3583
# Epoch 3 Batch 700 Loss 0.3438
# Epoch 3 Batch 800 Loss 0.4095
# Epoch 3 Batch 900 Loss 0.3651
# Epoch 3 Batch 1000 Loss 0.3205
# Epoch 3 Batch 1100 Loss 0.3752
# Epoch 3 Batch 1200 Loss 0.3359
# Epoch 3 Loss 0.3721
# Time taken for 1 epoch 216.5386517047882 sec
#
# Epoch 4 Batch 0 Loss 0.2318
# Epoch 4 Batch 100 Loss 0.1880
# Epoch 4 Batch 200 Loss 0.2065
# Epoch 4 Batch 300 Loss 0.2029
# Epoch 4 Batch 400 Loss 0.2255
# Epoch 4 Batch 500 Loss 0.2539
# Epoch 4 Batch 600 Loss 0.2277
# Epoch 4 Batch 700 Loss 0.2708
# Epoch 4 Batch 800 Loss 0.1800
# Epoch 4 Batch 900 Loss 0.1963
# Epoch 4 Batch 1000 Loss 0.2269
# Epoch 4 Batch 1100 Loss 0.2173
# Epoch 4 Batch 1200 Loss 0.2618
# Epoch 4 Loss 0.2184
# Time taken for 1 epoch 215.63217210769653 sec
#
# Epoch 5 Batch 0 Loss 0.1618
# Epoch 5 Batch 100 Loss 0.1372
# Epoch 5 Batch 200 Loss 0.1825
# Epoch 5 Batch 300 Loss 0.1438
# Epoch 5 Batch 400 Loss 0.1360
# Epoch 5 Batch 500 Loss 0.1331
# Epoch 5 Batch 600 Loss 0.1348
# Epoch 5 Batch 700 Loss 0.1596
# Epoch 5 Batch 800 Loss 0.1603
# Epoch 5 Batch 900 Loss 0.1621
# Epoch 5 Batch 1000 Loss 0.1500
# Epoch 5 Batch 1100 Loss 0.1777
# Epoch 5 Batch 1200 Loss 0.1490
# Epoch 5 Loss 0.1489
# Time taken for 1 epoch 215.91484355926514 sec
#
# Epoch 6 Batch 0 Loss 0.0888
# Epoch 6 Batch 100 Loss 0.1329
# Epoch 6 Batch 200 Loss 0.1064
# Epoch 6 Batch 300 Loss 0.1198
# Epoch 6 Batch 400 Loss 0.1392
# Epoch 6 Batch 500 Loss 0.1344
# Epoch 6 Batch 600 Loss 0.1021
# Epoch 6 Batch 700 Loss 0.1137
# Epoch 6 Batch 800 Loss 0.1524
# Epoch 6 Batch 900 Loss 0.0779
# Epoch 6 Batch 1000 Loss 0.1596
# Epoch 6 Batch 1100 Loss 0.1119
# Epoch 6 Batch 1200 Loss 0.1619
# Epoch 6 Loss 0.1165
# Time taken for 1 epoch 216.62424278259277 sec
#
# Epoch 7 Batch 0 Loss 0.0756
# Epoch 7 Batch 100 Loss 0.0629
# Epoch 7 Batch 200 Loss 0.0785
# Epoch 7 Batch 300 Loss 0.0826
# Epoch 7 Batch 400 Loss 0.0787
# Epoch 7 Batch 500 Loss 0.1251
# Epoch 7 Batch 600 Loss 0.0765
# Epoch 7 Batch 700 Loss 0.1263
# Epoch 7 Batch 800 Loss 0.0890
# Epoch 7 Batch 900 Loss 0.0996
# Epoch 7 Batch 1000 Loss 0.0826
# Epoch 7 Batch 1100 Loss 0.1028
# Epoch 7 Batch 1200 Loss 0.0990
# Epoch 7 Loss 0.0995
# Time taken for 1 epoch 215.15243291854858 sec
#
# Epoch 8 Batch 0 Loss 0.0468
# Epoch 8 Batch 100 Loss 0.0745
# Epoch 8 Batch 200 Loss 0.0925
# Epoch 8 Batch 300 Loss 0.1136
# Epoch 8 Batch 400 Loss 0.1035
# Epoch 8 Batch 500 Loss 0.0807
# Epoch 8 Batch 600 Loss 0.0896
# Epoch 8 Batch 700 Loss 0.1078
# Epoch 8 Batch 800 Loss 0.0972
# Epoch 8 Batch 900 Loss 0.0988
# Epoch 8 Batch 1000 Loss 0.1027
# Epoch 8 Batch 1100 Loss 0.0639
# Epoch 8 Batch 1200 Loss 0.0821
# Epoch 8 Loss 0.0914
# Time taken for 1 epoch 214.22923302650452 sec
#
# Epoch 9 Batch 0 Loss 0.0610
# Epoch 9 Batch 100 Loss 0.0910
# Epoch 9 Batch 200 Loss 0.0654
# Epoch 9 Batch 300 Loss 0.0797
# Epoch 9 Batch 400 Loss 0.0896
# Epoch 9 Batch 500 Loss 0.0600
# Epoch 9 Batch 600 Loss 0.0641
# Epoch 9 Batch 700 Loss 0.0792
# Epoch 9 Batch 800 Loss 0.1257
# Epoch 9 Batch 900 Loss 0.0797
# Epoch 9 Batch 1000 Loss 0.1108
# Epoch 9 Batch 1100 Loss 0.1024
# Epoch 9 Batch 1200 Loss 0.0922
# Epoch 9 Loss 0.0848
# Time taken for 1 epoch 219.34252953529358 sec
#
# Epoch 10 Batch 0 Loss 0.0679
# Epoch 10 Batch 100 Loss 0.0819
# Epoch 10 Batch 200 Loss 0.0500
# Epoch 10 Batch 300 Loss 0.0269
# Epoch 10 Batch 400 Loss 0.0655
# Epoch 10 Batch 500 Loss 0.0668
# Epoch 10 Batch 600 Loss 0.1286
# Epoch 10 Batch 700 Loss 0.0980
# Epoch 10 Batch 800 Loss 0.1322
# Epoch 10 Batch 900 Loss 0.0805
# Epoch 10 Batch 1000 Loss 0.1168
# Epoch 10 Batch 1100 Loss 0.1243
# Epoch 10 Batch 1200 Loss 0.0811
# Epoch 10 Loss 0.0816
# Time taken for 1 epoch 217.0384726524353 sec
#
# Epoch 11 Batch 0 Loss 0.0680
# Epoch 11 Batch 100 Loss 0.0492
# Epoch 11 Batch 200 Loss 0.0678
# Epoch 11 Batch 300 Loss 0.0201
# Epoch 11 Batch 400 Loss 0.0796
# Epoch 11 Batch 500 Loss 0.0696
# Epoch 11 Batch 600 Loss 0.1071
# Epoch 11 Batch 700 Loss 0.0790
# Epoch 11 Batch 800 Loss 0.0701
# Epoch 11 Batch 900 Loss 0.0928
# Epoch 11 Batch 1000 Loss 0.1130
# Epoch 11 Batch 1100 Loss 0.1213
# Epoch 11 Batch 1200 Loss 0.0936
# Epoch 11 Loss 0.0784
# Time taken for 1 epoch 218.61303162574768 sec
#
# Epoch 12 Batch 0 Loss 0.0581
# Epoch 12 Batch 100 Loss 0.0360
# Epoch 12 Batch 200 Loss 0.0796
# Epoch 12 Batch 300 Loss 0.0414
# Epoch 12 Batch 400 Loss 0.0636
# Epoch 12 Batch 500 Loss 0.0670
# Epoch 12 Batch 600 Loss 0.0756
# Epoch 12 Batch 700 Loss 0.0652
# Epoch 12 Batch 800 Loss 0.0853
# Epoch 12 Batch 900 Loss 0.0991
# Epoch 12 Batch 1000 Loss 0.0492
# Epoch 12 Batch 1100 Loss 0.0590
# Epoch 12 Batch 1200 Loss 0.0545
# Epoch 12 Loss 0.0751
# Time taken for 1 epoch 217.26925683021545 sec
#
# Epoch 13 Batch 0 Loss 0.0473
# Epoch 13 Batch 100 Loss 0.1026
# Epoch 13 Batch 200 Loss 0.0537
# Epoch 13 Batch 300 Loss 0.0433
# Epoch 13 Batch 400 Loss 0.0301
# Epoch 13 Batch 500 Loss 0.0579
# Epoch 13 Batch 600 Loss 0.0667
# Epoch 13 Batch 700 Loss 0.0466
# Epoch 13 Batch 800 Loss 0.1455
# Epoch 13 Batch 900 Loss 0.0496
# Epoch 13 Batch 1000 Loss 0.0583
# Epoch 13 Batch 1100 Loss 0.1208
# Epoch 13 Batch 1200 Loss 0.0863
# Epoch 13 Loss 0.0729
# Time taken for 1 epoch 216.53841543197632 sec
#
# Epoch 14 Batch 0 Loss 0.0448
# Epoch 14 Batch 100 Loss 0.0561
# Epoch 14 Batch 200 Loss 0.0454
# Epoch 14 Batch 300 Loss 0.0633
# Epoch 14 Batch 400 Loss 0.0661
# Epoch 14 Batch 500 Loss 0.0372
# Epoch 14 Batch 600 Loss 0.1293
# Epoch 14 Batch 700 Loss 0.0664
# Epoch 14 Batch 800 Loss 0.0753
# Epoch 14 Batch 900 Loss 0.0624
# Epoch 14 Batch 1000 Loss 0.0729
# Epoch 14 Batch 1100 Loss 0.0887
# Epoch 14 Batch 1200 Loss 0.0913
# Epoch 14 Loss 0.0712
# Time taken for 1 epoch 222.32855081558228 sec
#
# Epoch 15 Batch 0 Loss 0.0489
# Epoch 15 Batch 100 Loss 0.0748
# Epoch 15 Batch 200 Loss 0.0667
# Epoch 15 Batch 300 Loss 0.0334
# Epoch 15 Batch 400 Loss 0.0828
# Epoch 15 Batch 500 Loss 0.0592
# Epoch 15 Batch 600 Loss 0.0748
# Epoch 15 Batch 700 Loss 0.0718
# Epoch 15 Batch 800 Loss 0.0721
# Epoch 15 Batch 900 Loss 0.0596
# Epoch 15 Batch 1000 Loss 0.0838
# Epoch 15 Batch 1100 Loss 0.0997
# Epoch 15 Batch 1200 Loss 0.0650
# Epoch 15 Loss 0.0695
# Time taken for 1 epoch 219.3789598941803 sec
#
# Epoch 16 Batch 0 Loss 0.0377
# Epoch 16 Batch 100 Loss 0.0812
# Epoch 16 Batch 200 Loss 0.0583
# Epoch 16 Batch 300 Loss 0.0439
# Epoch 16 Batch 400 Loss 0.1004
# Epoch 16 Batch 500 Loss 0.0734
# Epoch 16 Batch 600 Loss 0.0907
# Epoch 16 Batch 700 Loss 0.0555
# Epoch 16 Batch 800 Loss 0.0281
# Epoch 16 Batch 900 Loss 0.0962
# Epoch 16 Batch 1000 Loss 0.0678
# Epoch 16 Batch 1100 Loss 0.0846
# Epoch 16 Batch 1200 Loss 0.0668
# Epoch 16 Loss 0.0677
# Time taken for 1 epoch 222.97101712226868 sec
#
# Epoch 17 Batch 0 Loss 0.0416
# Epoch 17 Batch 100 Loss 0.0248
# Epoch 17 Batch 200 Loss 0.0382
# Epoch 17 Batch 300 Loss 0.0478
# Epoch 17 Batch 400 Loss 0.0344
# Epoch 17 Batch 500 Loss 0.0735
# Epoch 17 Batch 600 Loss 0.0709
# Epoch 17 Batch 700 Loss 0.0572
# Epoch 17 Batch 800 Loss 0.0562
# Epoch 17 Batch 900 Loss 0.1070
# Epoch 17 Batch 1000 Loss 0.0805
# Epoch 17 Batch 1100 Loss 0.0562
# Epoch 17 Batch 1200 Loss 0.0885
# Epoch 17 Loss 0.0670
# Time taken for 1 epoch 220.5168652534485 sec
#
# Epoch 18 Batch 0 Loss 0.0701
# Epoch 18 Batch 100 Loss 0.0314
# Epoch 18 Batch 200 Loss 0.0631
# Epoch 18 Batch 300 Loss 0.0442
# Epoch 18 Batch 400 Loss 0.0472
# Epoch 18 Batch 500 Loss 0.0685
# Epoch 18 Batch 600 Loss 0.0425
# Epoch 18 Batch 700 Loss 0.0709
# Epoch 18 Batch 800 Loss 0.0766
# Epoch 18 Batch 900 Loss 0.0517
# Epoch 18 Batch 1000 Loss 0.0761
# Epoch 18 Batch 1100 Loss 0.0601
# Epoch 18 Batch 1200 Loss 0.0737
# Epoch 18 Loss 0.0654
# Time taken for 1 epoch 218.87837100028992 sec
#
# Epoch 19 Batch 0 Loss 0.0666
# Epoch 19 Batch 100 Loss 0.0521
# Epoch 19 Batch 200 Loss 0.0423
# Epoch 19 Batch 300 Loss 0.0473
# Epoch 19 Batch 400 Loss 0.0651
# Epoch 19 Batch 500 Loss 0.0640
# Epoch 19 Batch 600 Loss 0.0855
# Epoch 19 Batch 700 Loss 0.0549
# Epoch 19 Batch 800 Loss 0.0548
# Epoch 19 Batch 900 Loss 0.0557
# Epoch 19 Batch 1000 Loss 0.0706
# Epoch 19 Batch 1100 Loss 0.0740
# Epoch 19 Batch 1200 Loss 0.0758
# Epoch 19 Loss 0.0643
# Time taken for 1 epoch 218.53991150856018 sec
#
# Epoch 20 Batch 0 Loss 0.0791
# Epoch 20 Batch 100 Loss 0.0339
# Epoch 20 Batch 200 Loss 0.0667
# Epoch 20 Batch 300 Loss 0.0375
# Epoch 20 Batch 400 Loss 0.0691
# Epoch 20 Batch 500 Loss 0.0567
# Epoch 20 Batch 600 Loss 0.0905
# Epoch 20 Batch 700 Loss 0.0875
# Epoch 20 Batch 800 Loss 0.0563
# Epoch 20 Batch 900 Loss 0.0496
# Epoch 20 Batch 1000 Loss 0.0681
# Epoch 20 Batch 1100 Loss 0.0856
# Epoch 20 Batch 1200 Loss 0.0899
# Epoch 20 Loss 0.0626
# Time taken for 1 epoch 217.55318188667297 sec
#
# Epoch 21 Batch 0 Loss 0.0485
# Epoch 21 Batch 100 Loss 0.0336
# Epoch 21 Batch 200 Loss 0.0344
# Epoch 21 Batch 300 Loss 0.1306
# Epoch 21 Batch 400 Loss 0.0871
# Epoch 21 Batch 500 Loss 0.0325
# Epoch 21 Batch 600 Loss 0.0773
# Epoch 21 Batch 700 Loss 0.0798
# Epoch 21 Batch 800 Loss 0.0659
# Epoch 21 Batch 900 Loss 0.0536
# Epoch 21 Batch 1000 Loss 0.0365
# Epoch 21 Batch 1100 Loss 0.0702
# Epoch 21 Batch 1200 Loss 0.0548
# Epoch 21 Loss 0.0621
# Time taken for 1 epoch 213.68317675590515 sec
#
# Epoch 22 Batch 0 Loss 0.0285
# Epoch 22 Batch 100 Loss 0.0700
# Epoch 22 Batch 200 Loss 0.0727
# Epoch 22 Batch 300 Loss 0.0680
# Epoch 22 Batch 400 Loss 0.0663
# Epoch 22 Batch 500 Loss 0.0655
# Epoch 22 Batch 600 Loss 0.0638
# Epoch 22 Batch 700 Loss 0.0510
# Epoch 22 Batch 800 Loss 0.0483
# Epoch 22 Batch 900 Loss 0.0723
# Epoch 22 Batch 1000 Loss 0.0796
# Epoch 22 Batch 1100 Loss 0.0672
# Epoch 22 Batch 1200 Loss 0.0522
# Epoch 22 Loss 0.0610
# Time taken for 1 epoch 213.87400126457214 sec
#
# Epoch 23 Batch 0 Loss 0.0344
# Epoch 23 Batch 100 Loss 0.0429
# Epoch 23 Batch 200 Loss 0.0312
# Epoch 23 Batch 300 Loss 0.0705
# Epoch 23 Batch 400 Loss 0.0706
# Epoch 23 Batch 500 Loss 0.0727
# Epoch 23 Batch 600 Loss 0.0702
# Epoch 23 Batch 700 Loss 0.0420
# Epoch 23 Batch 800 Loss 0.0687
# Epoch 23 Batch 900 Loss 0.0565
# Epoch 23 Batch 1000 Loss 0.0486
# Epoch 23 Batch 1100 Loss 0.0891
# Epoch 23 Batch 1200 Loss 0.0821
# Epoch 23 Loss 0.0603
# Time taken for 1 epoch 215.36758637428284 sec
#
# Epoch 24 Batch 0 Loss 0.0371
# Epoch 24 Batch 100 Loss 0.0371
# Epoch 24 Batch 200 Loss 0.0398
# Epoch 24 Batch 300 Loss 0.0366
# Epoch 24 Batch 400 Loss 0.0485
# Epoch 24 Batch 500 Loss 0.0401
# Epoch 24 Batch 600 Loss 0.0432
# Epoch 24 Batch 700 Loss 0.0770
# Epoch 24 Batch 800 Loss 0.0627
# Epoch 24 Batch 900 Loss 0.0670
# Epoch 24 Batch 1000 Loss 0.0418
# Epoch 24 Batch 1100 Loss 0.0444
# Epoch 24 Batch 1200 Loss 0.0560
# Epoch 24 Loss 0.0593
# Time taken for 1 epoch 218.26053166389465 sec
#
# Epoch 25 Batch 0 Loss 0.0397
# Epoch 25 Batch 100 Loss 0.0216
# Epoch 25 Batch 200 Loss 0.0590
# Epoch 25 Batch 300 Loss 0.0502
# Epoch 25 Batch 400 Loss 0.0223
# Epoch 25 Batch 500 Loss 0.0382
# Epoch 25 Batch 600 Loss 0.0475
# Epoch 25 Batch 700 Loss 0.0364
# Epoch 25 Batch 800 Loss 0.0689
# Epoch 25 Batch 900 Loss 0.0629
# Epoch 25 Batch 1000 Loss 0.0813
# Epoch 25 Batch 1100 Loss 0.0903
# Epoch 25 Batch 1200 Loss 0.0875
# Epoch 25 Loss 0.0583
# Time taken for 1 epoch 216.27890849113464 sec
#
# Epoch 26 Batch 0 Loss 0.0280
# Epoch 26 Batch 100 Loss 0.0892
# Epoch 26 Batch 200 Loss 0.0486
# Epoch 26 Batch 300 Loss 0.0729
# Epoch 26 Batch 400 Loss 0.0550
# Epoch 26 Batch 500 Loss 0.0495
# Epoch 26 Batch 600 Loss 0.0418
# Epoch 26 Batch 700 Loss 0.0598
# Epoch 26 Batch 800 Loss 0.0832
# Epoch 26 Batch 900 Loss 0.0368
# Epoch 26 Batch 1000 Loss 0.0618
# Epoch 26 Batch 1100 Loss 0.0927
# Epoch 26 Batch 1200 Loss 0.0623
# Epoch 26 Loss 0.0583
# Time taken for 1 epoch 217.640953540802 sec
#
# Epoch 27 Batch 0 Loss 0.0649
# Epoch 27 Batch 100 Loss 0.0349
# Epoch 27 Batch 200 Loss 0.0318
# Epoch 27 Batch 300 Loss 0.0533
# Epoch 27 Batch 400 Loss 0.0504
# Epoch 27 Batch 500 Loss 0.0558
# Epoch 27 Batch 600 Loss 0.0378
# Epoch 27 Batch 700 Loss 0.0598
# Epoch 27 Batch 800 Loss 0.1007
# Epoch 27 Batch 900 Loss 0.0757
# Epoch 27 Batch 1000 Loss 0.0720
# Epoch 27 Batch 1100 Loss 0.0703
# Epoch 27 Batch 1200 Loss 0.0479
# Epoch 27 Loss 0.0565
# Time taken for 1 epoch 218.8958351612091 sec
#
# Epoch 28 Batch 0 Loss 0.0369
# Epoch 28 Batch 100 Loss 0.0491
# Epoch 28 Batch 200 Loss 0.0367
# Epoch 28 Batch 300 Loss 0.0592
# Epoch 28 Batch 400 Loss 0.0817
# Epoch 28 Batch 500 Loss 0.0440
# Epoch 28 Batch 600 Loss 0.0444
# Epoch 28 Batch 700 Loss 0.0632
# Epoch 28 Batch 800 Loss 0.0687
# Epoch 28 Batch 900 Loss 0.0727
# Epoch 28 Batch 1000 Loss 0.1013
# Epoch 28 Batch 1100 Loss 0.0528
# Epoch 28 Batch 1200 Loss 0.0380
# Epoch 28 Loss 0.0565
# Time taken for 1 epoch 220.1941156387329 sec
#
# Epoch 29 Batch 0 Loss 0.0358
# Epoch 29 Batch 100 Loss 0.0386
# Epoch 29 Batch 200 Loss 0.0749
# Epoch 29 Batch 300 Loss 0.0678
# Epoch 29 Batch 400 Loss 0.0349
# Epoch 29 Batch 500 Loss 0.0445
# Epoch 29 Batch 600 Loss 0.0525
# Epoch 29 Batch 700 Loss 0.0626
# Epoch 29 Batch 800 Loss 0.0839
# Epoch 29 Batch 900 Loss 0.0495
# Epoch 29 Batch 1000 Loss 0.0614
# Epoch 29 Batch 1100 Loss 0.0625
# Epoch 29 Batch 1200 Loss 0.0496
# Epoch 29 Loss 0.0552
# Time taken for 1 epoch 218.71969652175903 sec
#
# Epoch 30 Batch 0 Loss 0.0444
# Epoch 30 Batch 100 Loss 0.0148
# Epoch 30 Batch 200 Loss 0.0460
# Epoch 30 Batch 300 Loss 0.0448
# Epoch 30 Batch 400 Loss 0.0547
# Epoch 30 Batch 500 Loss 0.0447
# Epoch 30 Batch 600 Loss 0.0476
# Epoch 30 Batch 700 Loss 0.0272
# Epoch 30 Batch 800 Loss 0.0221
# Epoch 30 Batch 900 Loss 0.0579
# Epoch 30 Batch 1000 Loss 0.0708
# Epoch 30 Batch 1100 Loss 0.0435
# Epoch 30 Batch 1200 Loss 0.0805
# Epoch 30 Loss 0.0547
# Time taken for 1 epoch 221.6323390007019 sec
#
# Epoch 31 Batch 0 Loss 0.0695
# Epoch 31 Batch 100 Loss 0.0739
# Epoch 31 Batch 200 Loss 0.0367
# Epoch 31 Batch 300 Loss 0.0424
# Epoch 31 Batch 400 Loss 0.0430
# Epoch 31 Batch 500 Loss 0.0751
# Epoch 31 Batch 600 Loss 0.0468
# Epoch 31 Batch 700 Loss 0.0739
# Epoch 31 Batch 800 Loss 0.0506
# Epoch 31 Batch 900 Loss 0.0702
# Epoch 31 Batch 1000 Loss 0.0520
# Epoch 31 Batch 1100 Loss 0.0590
# Epoch 31 Batch 1200 Loss 0.0580
# Epoch 31 Loss 0.0542
# Time taken for 1 epoch 222.5027346611023 sec
#
# Epoch 32 Batch 0 Loss 0.0525
# Epoch 32 Batch 100 Loss 0.0360
# Epoch 32 Batch 200 Loss 0.0296
# Epoch 32 Batch 300 Loss 0.0627
# Epoch 32 Batch 400 Loss 0.0439
# Epoch 32 Batch 500 Loss 0.0395
# Epoch 32 Batch 600 Loss 0.0713
# Epoch 32 Batch 700 Loss 0.0706
# Epoch 32 Batch 800 Loss 0.0474
# Epoch 32 Batch 900 Loss 0.0810
# Epoch 32 Batch 1000 Loss 0.0462
# Epoch 32 Batch 1100 Loss 0.0442
# Epoch 32 Batch 1200 Loss 0.0459
# Epoch 32 Loss 0.0530
# Time taken for 1 epoch 222.49268579483032 sec
#
# Epoch 33 Batch 0 Loss 0.0403
# Epoch 33 Batch 100 Loss 0.0527
# Epoch 33 Batch 200 Loss 0.0935
# Epoch 33 Batch 300 Loss 0.0393
# Epoch 33 Batch 400 Loss 0.0680
# Epoch 33 Batch 500 Loss 0.0469
# Epoch 33 Batch 600 Loss 0.0573
# Epoch 33 Batch 700 Loss 0.0598
# Epoch 33 Batch 800 Loss 0.0645
# Epoch 33 Batch 900 Loss 0.0880
# Epoch 33 Batch 1000 Loss 0.0568
# Epoch 33 Batch 1100 Loss 0.1002
# Epoch 33 Batch 1200 Loss 0.0662
# Epoch 33 Loss 0.0527
# Time taken for 1 epoch 223.04153680801392 sec
#
# Epoch 34 Batch 0 Loss 0.0686
# Epoch 34 Batch 100 Loss 0.0389
# Epoch 34 Batch 200 Loss 0.0549
# Epoch 34 Batch 300 Loss 0.0453
# Epoch 34 Batch 400 Loss 0.0231
# Epoch 34 Batch 500 Loss 0.0574
# Epoch 34 Batch 600 Loss 0.0457
# Epoch 34 Batch 700 Loss 0.0632
# Epoch 34 Batch 800 Loss 0.0658
# Epoch 34 Batch 900 Loss 0.0525
# Epoch 34 Batch 1000 Loss 0.0564
# Epoch 34 Batch 1100 Loss 0.0532
# Epoch 34 Batch 1200 Loss 0.0765
# Epoch 34 Loss 0.0515
# Time taken for 1 epoch 220.79330611228943 sec
#
# Epoch 35 Batch 0 Loss 0.0450
# Epoch 35 Batch 100 Loss 0.0359
# Epoch 35 Batch 200 Loss 0.0496
# Epoch 35 Batch 300 Loss 0.0362
# Epoch 35 Batch 400 Loss 0.0571
# Epoch 35 Batch 500 Loss 0.0434
# Epoch 35 Batch 600 Loss 0.0685
# Epoch 35 Batch 700 Loss 0.0531
# Epoch 35 Batch 800 Loss 0.0447
# Epoch 35 Batch 900 Loss 0.0396
# Epoch 35 Batch 1000 Loss 0.0418
# Epoch 35 Batch 1100 Loss 0.0610
# Epoch 35 Batch 1200 Loss 0.0456
# Epoch 35 Loss 0.0518
# Time taken for 1 epoch 216.74547243118286 sec
#
# Epoch 36 Batch 0 Loss 0.0386
# Epoch 36 Batch 100 Loss 0.0433
# Epoch 36 Batch 200 Loss 0.0351
# Epoch 36 Batch 300 Loss 0.0339
# Epoch 36 Batch 400 Loss 0.0569
# Epoch 36 Batch 500 Loss 0.0356
# Epoch 36 Batch 600 Loss 0.0609
# Epoch 36 Batch 700 Loss 0.0537
# Epoch 36 Batch 800 Loss 0.0666
# Epoch 36 Batch 900 Loss 0.0545
# Epoch 36 Batch 1000 Loss 0.0498
# Epoch 36 Batch 1100 Loss 0.0387
# Epoch 36 Batch 1200 Loss 0.0269
# Epoch 36 Loss 0.0511
# Time taken for 1 epoch 219.7645993232727 sec
#
# Epoch 37 Batch 0 Loss 0.0530
# Epoch 37 Batch 100 Loss 0.0398
# Epoch 37 Batch 200 Loss 0.0525
# Epoch 37 Batch 300 Loss 0.0243
# Epoch 37 Batch 400 Loss 0.0368
# Epoch 37 Batch 500 Loss 0.0348
# Epoch 37 Batch 600 Loss 0.0529
# Epoch 37 Batch 700 Loss 0.0520
# Epoch 37 Batch 800 Loss 0.0694
# Epoch 37 Batch 900 Loss 0.0549
# Epoch 37 Batch 1000 Loss 0.0468
# Epoch 37 Batch 1100 Loss 0.0327
# Epoch 37 Batch 1200 Loss 0.0683
# Epoch 37 Loss 0.0508
# Time taken for 1 epoch 220.21331453323364 sec
#
# Epoch 38 Batch 0 Loss 0.0636
# Epoch 38 Batch 100 Loss 0.0696
# Epoch 38 Batch 200 Loss 0.0393
# Epoch 38 Batch 300 Loss 0.0550
# Epoch 38 Batch 400 Loss 0.0411
# Epoch 38 Batch 500 Loss 0.0405
# Epoch 38 Batch 600 Loss 0.0633
# Epoch 38 Batch 700 Loss 0.0800
# Epoch 38 Batch 800 Loss 0.0237
# Epoch 38 Batch 900 Loss 0.0542
# Epoch 38 Batch 1000 Loss 0.0329
# Epoch 38 Batch 1100 Loss 0.0702
# Epoch 38 Batch 1200 Loss 0.0795
# Epoch 38 Loss 0.0493
# Time taken for 1 epoch 219.91023111343384 sec
#
# Epoch 39 Batch 0 Loss 0.0584
# Epoch 39 Batch 100 Loss 0.0251
# Epoch 39 Batch 200 Loss 0.0350
# Epoch 39 Batch 300 Loss 0.0339
# Epoch 39 Batch 400 Loss 0.0475
# Epoch 39 Batch 500 Loss 0.0775
# Epoch 39 Batch 600 Loss 0.0530
# Epoch 39 Batch 700 Loss 0.0595
# Epoch 39 Batch 800 Loss 0.0489
# Epoch 39 Batch 900 Loss 0.0505
# Epoch 39 Batch 1000 Loss 0.0785
# Epoch 39 Batch 1100 Loss 0.0770
# Epoch 39 Batch 1200 Loss 0.0732
# Epoch 39 Loss 0.0494
# Time taken for 1 epoch 221.06702423095703 sec
#
# Epoch 40 Batch 0 Loss 0.0312
# Epoch 40 Batch 100 Loss 0.0371
# Epoch 40 Batch 200 Loss 0.0265
# Epoch 40 Batch 300 Loss 0.0260
# Epoch 40 Batch 400 Loss 0.0512
# Epoch 40 Batch 500 Loss 0.0514
# Epoch 40 Batch 600 Loss 0.0582
# Epoch 40 Batch 700 Loss 0.0587
# Epoch 40 Batch 800 Loss 0.0593
# Epoch 40 Batch 900 Loss 0.0334
# Epoch 40 Batch 1000 Loss 0.0523
# Epoch 40 Batch 1100 Loss 0.0409
# Epoch 40 Batch 1200 Loss 0.0382
# Epoch 40 Loss 0.0496
# Time taken for 1 epoch 223.55657076835632 sec
#
# Epoch 41 Batch 0 Loss 0.0164
# Epoch 41 Batch 100 Loss 0.0318
# Epoch 41 Batch 200 Loss 0.0370
# Epoch 41 Batch 300 Loss 0.0345
# Epoch 41 Batch 400 Loss 0.0227
# Epoch 41 Batch 500 Loss 0.0515
# Epoch 41 Batch 600 Loss 0.0610
# Epoch 41 Batch 700 Loss 0.0501
# Epoch 41 Batch 800 Loss 0.0594
# Epoch 41 Batch 900 Loss 0.0522
# Epoch 41 Batch 1000 Loss 0.0636
# Epoch 41 Batch 1100 Loss 0.0774
# Epoch 41 Batch 1200 Loss 0.0720
# Epoch 41 Loss 0.0488
# Time taken for 1 epoch 220.28305959701538 sec
#
# Epoch 42 Batch 0 Loss 0.0294
# Epoch 42 Batch 100 Loss 0.0543
# Epoch 42 Batch 200 Loss 0.0340
# Epoch 42 Batch 300 Loss 0.0570
# Epoch 42 Batch 400 Loss 0.0326
# Epoch 42 Batch 500 Loss 0.0706
# Epoch 42 Batch 600 Loss 0.0608
# Epoch 42 Batch 700 Loss 0.0348
# Epoch 42 Batch 800 Loss 0.0465
# Epoch 42 Batch 900 Loss 0.0478
# Epoch 42 Batch 1000 Loss 0.0502
# Epoch 42 Batch 1100 Loss 0.0416
# Epoch 42 Batch 1200 Loss 0.0458
# Epoch 42 Loss 0.0481
# Time taken for 1 epoch 222.19590711593628 sec
#
# Epoch 43 Batch 0 Loss 0.0275
# Epoch 43 Batch 100 Loss 0.0569
# Epoch 43 Batch 200 Loss 0.0618
# Epoch 43 Batch 300 Loss 0.0356
# Epoch 43 Batch 400 Loss 0.0492
# Epoch 43 Batch 500 Loss 0.0495
# Epoch 43 Batch 600 Loss 0.0551
# Epoch 43 Batch 700 Loss 0.0507
# Epoch 43 Batch 800 Loss 0.0181
# Epoch 43 Batch 900 Loss 0.0441
# Epoch 43 Batch 1000 Loss 0.0556
# Epoch 43 Batch 1100 Loss 0.0561
# Epoch 43 Batch 1200 Loss 0.0395
# Epoch 43 Loss 0.0483
# Time taken for 1 epoch 217.6207959651947 sec
#
# Epoch 44 Batch 0 Loss 0.0290
# Epoch 44 Batch 100 Loss 0.0568
# Epoch 44 Batch 200 Loss 0.0350
# Epoch 44 Batch 300 Loss 0.0866
# Epoch 44 Batch 400 Loss 0.0379
# Epoch 44 Batch 500 Loss 0.0555
# Epoch 44 Batch 600 Loss 0.0557
# Epoch 44 Batch 700 Loss 0.0473
# Epoch 44 Batch 800 Loss 0.0453
# Epoch 44 Batch 900 Loss 0.0724
# Epoch 44 Batch 1000 Loss 0.0452
# Epoch 44 Batch 1100 Loss 0.1051
# Epoch 44 Batch 1200 Loss 0.0480
# Epoch 44 Loss 0.0475
# Time taken for 1 epoch 223.07285809516907 sec
#
# Epoch 45 Batch 0 Loss 0.0283
# Epoch 45 Batch 100 Loss 0.0261
# Epoch 45 Batch 200 Loss 0.0289
# Epoch 45 Batch 300 Loss 0.0299
# Epoch 45 Batch 400 Loss 0.0590
# Epoch 45 Batch 500 Loss 0.0251
# Epoch 45 Batch 600 Loss 0.0274
# Epoch 45 Batch 700 Loss 0.0439
# Epoch 45 Batch 800 Loss 0.0522
# Epoch 45 Batch 900 Loss 0.0498
# Epoch 45 Batch 1000 Loss 0.0609
# Epoch 45 Batch 1100 Loss 0.0642
# Epoch 45 Batch 1200 Loss 0.0723
# Epoch 45 Loss 0.0463
# Time taken for 1 epoch 227.21423387527466 sec
#
# Epoch 46 Batch 0 Loss 0.0381
# Epoch 46 Batch 100 Loss 0.0249
# Epoch 46 Batch 200 Loss 0.0613
# Epoch 46 Batch 300 Loss 0.0447
# Epoch 46 Batch 400 Loss 0.0502
# Epoch 46 Batch 500 Loss 0.0520
# Epoch 46 Batch 600 Loss 0.0451
# Epoch 46 Batch 700 Loss 0.0541
# Epoch 46 Batch 800 Loss 0.0355
# Epoch 46 Batch 900 Loss 0.0474
# Epoch 46 Batch 1000 Loss 0.0587
# Epoch 46 Batch 1100 Loss 0.0379
# Epoch 46 Batch 1200 Loss 0.0641
# Epoch 46 Loss 0.0465
# Time taken for 1 epoch 221.70850706100464 sec
#
# Epoch 47 Batch 0 Loss 0.0165
# Epoch 47 Batch 100 Loss 0.0412
# Epoch 47 Batch 200 Loss 0.0258
# Epoch 47 Batch 300 Loss 0.0329
# Epoch 47 Batch 400 Loss 0.0351
# Epoch 47 Batch 500 Loss 0.0609
# Epoch 47 Batch 600 Loss 0.0351
# Epoch 47 Batch 700 Loss 0.0445
# Epoch 47 Batch 800 Loss 0.0545
# Epoch 47 Batch 900 Loss 0.0532
# Epoch 47 Batch 1000 Loss 0.0953
# Epoch 47 Batch 1100 Loss 0.0582
# Epoch 47 Batch 1200 Loss 0.0837
# Epoch 47 Loss 0.0467
# Time taken for 1 epoch 216.8959686756134 sec
#
# Epoch 48 Batch 0 Loss 0.0398
# Epoch 48 Batch 100 Loss 0.0604
# Epoch 48 Batch 200 Loss 0.0245
# Epoch 48 Batch 300 Loss 0.0523
# Epoch 48 Batch 400 Loss 0.0641
# Epoch 48 Batch 500 Loss 0.0541
# Epoch 48 Batch 600 Loss 0.0248
# Epoch 48 Batch 700 Loss 0.0616
# Epoch 48 Batch 800 Loss 0.0439
# Epoch 48 Batch 900 Loss 0.0529
# Epoch 48 Batch 1000 Loss 0.0536
# Epoch 48 Batch 1100 Loss 0.0601
# Epoch 48 Batch 1200 Loss 0.0300
# Epoch 48 Loss 0.0465
# Time taken for 1 epoch 215.19373869895935 sec
#
# Epoch 49 Batch 0 Loss 0.0578
# Epoch 49 Batch 100 Loss 0.0474
# Epoch 49 Batch 200 Loss 0.0298
# Epoch 49 Batch 300 Loss 0.0518
# Epoch 49 Batch 400 Loss 0.0466
# Epoch 49 Batch 500 Loss 0.0627
# Epoch 49 Batch 600 Loss 0.0343
# Epoch 49 Batch 700 Loss 0.0486
# Epoch 49 Batch 800 Loss 0.0372
# Epoch 49 Batch 900 Loss 0.0351
# Epoch 49 Batch 1000 Loss 0.0340
# Epoch 49 Batch 1100 Loss 0.0435
# Epoch 49 Batch 1200 Loss 0.0384
# Epoch 49 Loss 0.0462
# Time taken for 1 epoch 215.3034815788269 sec
#
# Epoch 50 Batch 0 Loss 0.0395
# Epoch 50 Batch 100 Loss 0.0274
# Epoch 50 Batch 200 Loss 0.0270
# Epoch 50 Batch 300 Loss 0.0409
# Epoch 50 Batch 400 Loss 0.0308
# Epoch 50 Batch 500 Loss 0.0448
# Epoch 50 Batch 600 Loss 0.0485
# Epoch 50 Batch 700 Loss 0.0484
# Epoch 50 Batch 800 Loss 0.0393
# Epoch 50 Batch 900 Loss 0.0210
# Epoch 50 Batch 1000 Loss 0.0539
# Epoch 50 Batch 1100 Loss 0.0766
# Epoch 50 Batch 1200 Loss 0.0285
# Epoch 50 Loss 0.0452
# Time taken for 1 epoch 214.42868423461914 sec

# %% [markdown]
# ## Translate
#
# * The evaluate function is similar to the training loop, except we don't use *teacher forcing* here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the *end token*.
# * And store the *attention weights for every time step*.
#
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's good news . <end>

# %%
translate('Я не смогу поехать.')
# Out:
# Input: <start> я не смогу поехать . <end>
# Predicted translation: i can't go . <end>

# %%
translate(u'Вы еще дома?')
# Out:
# Input: <start> вы еще дома ? <end>
# Predicted translation: are you still at home ? <end>

# %%
translate(u'Вы все еще дома?')
# Out:
# Input: <start> вы все еще дома ? <end>
# Predicted translation: can you still home ? <end>

# %%
translate(u'Попробуй сделать это.')
# Out:
# Input: <start> попробуй сделать это . <end>
# Predicted translation: try to do that . <end>

# %%
translate(u'Я люблю, когда идет снег.')
# Out:
# Input: <start> я люблю , когда идет снег . <end>
# Predicted translation: i love the time snow . <end>

# %%
translate(u'Я никогда такого не делаю.')
# Out:
# Input: <start> я никогда такого не делаю . <end>
# Predicted translation: i never do that . <end>
